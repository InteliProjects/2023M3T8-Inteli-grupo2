# %%
#Neste notebook, as colunas 'created_at', 'updated_at' e 'average_distance' foram removidas pois não foram utilizadas.

#preprocessing is done
import pandas as pd

df_jb_opp_superfit = pd.read_csv('Dados - bettha/job_opportunity_superfit_consolidates.csv')

# %%
df_jb_opp_superfit
# Out:
#        id  job_opportunity_id  score_res  score_eng  score_int  score_cur  \
# 0    1815                2727       44.0       40.0       38.0       38.0
# 1    1816                2686       42.0       34.0       44.0       28.0
# 2    1928                2900       38.0       20.0       36.0       30.0
# 3    1862                2755       26.0       30.0       34.0       24.0
# 4    1817                2749       24.0       16.0       42.0       20.0
# ..    ...                 ...        ...        ...        ...        ...
# 164  1980                2947       28.0       26.0       36.0       34.0
# 165  1979                2963       30.0       26.0       26.0       20.0
# 166  1981                2965       38.0       36.0       36.0       34.0
# 167  1982                2967       36.0       34.0       40.0       26.0
# 168  1983                2907       32.0       14.0       24.0       16.0
#
#      score_sin  score_dis                  created_at  \
# ...

# %%
df_jb_opp_superfit.drop('average_distance', axis=1, inplace=True)
df_jb_opp_superfit.drop('created_at', axis=1, inplace=True)
df_jb_opp_superfit.drop('updated_at', axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 df_jb_opp_superfit.drop('average_distance', axis=1, inplace=True)
#
# File ~\anaconda3\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5399, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5251 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    5252 def drop(  # type: ignore[override]
#    5253     self,
# ...

# %%
df_jb_opp_superfit
# Out:
#        id  job_opportunity_id  score_res  score_eng  score_int  score_cur  \
# 0    1815                2727       44.0       40.0       38.0       38.0
# 1    1816                2686       42.0       34.0       44.0       28.0
# 2    1928                2900       38.0       20.0       36.0       30.0
# 3    1862                2755       26.0       30.0       34.0       24.0
# 4    1817                2749       24.0       16.0       42.0       20.0
# ..    ...                 ...        ...        ...        ...        ...
# 164  1980                2947       28.0       26.0       36.0       34.0
# 165  1979                2963       30.0       26.0       26.0       20.0
# 166  1981                2965       38.0       36.0       36.0       34.0
# 167  1982                2967       36.0       34.0       40.0       26.0
# 168  1983                2907       32.0       14.0       24.0       16.0
#
#      score_sin  score_dis                  created_at  \
# ...

# %%
df_jb_opp_superfit.to_csv('prep_df_jb_opp_superfit.csv')
